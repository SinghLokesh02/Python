# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Selecting one Column

# %% [markdown]
# #### 1.1 Syntax 1

# %%
df_matches = pd.read_csv("matches - matches.csv")
df_matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# Select a column with [](Preferred way to select columns)

df_matches["winner"]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
# Check out Datatype of a column
type(df_matches["win_by_wickets"])
# Out:
# pandas.core.series.Series

# %%
# Series : attributes and Methods
df_matches["winner"].index
df_matches["winner"].head()
# Out:
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# Name: winner, dtype: object

# %% [markdown]
# #### 1.2 Syntax 2

# %%
# Select a column with
df_matches.winner
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
# Select a column with .
# df_matches.toss decision -> This is wrong for this type of column either you use _ for space or use [] method for print

# Method 1 Using _ for spaces
df_matches.toss_decision
# Out:
# 0      field
# 1      field
# 2      field
# 3      field
# 4        bat
#        ...
# 631    field
# 632    field
# 633    field
# 634    field
# 635      bat
# Name: toss_decision, Length: 636, dtype: object

# %%
# Select column with []
df_matches["toss_decision"]
# Out:
# 0      field
# 1      field
# 2      field
# 3      field
# 4        bat
#        ...
# 631    field
# 632    field
# 633    field
# 634    field
# 635      bat
# Name: toss_decision, Length: 636, dtype: object

# %% [markdown]
# ## 1 Selecting two or more Columns

# %%
# Select two columns using [[]]
df_matches[["winner", "toss_decision"]]
# Out:
#                           winner toss_decision
# 0            Sunrisers Hyderabad         field
# 1         Rising Pune Supergiant         field
# 2          Kolkata Knight Riders         field
# 3                Kings XI Punjab         field
# 4    Royal Challengers Bangalore           bat
# ..                           ...           ...
# 631  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore         field
# 633          Sunrisers Hyderabad         field
# 634          Sunrisers Hyderabad         field
# 635          Sunrisers Hyderabad           bat
#
# [636 rows x 2 columns]

# %%
# Check out The data type of the selection
type(df_matches[["winner", "toss_decision"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# Select 2 or more columns using [[]]
ans = df_matches[["winner", "toss_decision", "city", "date", "season"]].head(3)
ans
# Out:
#                    winner toss_decision       city        date  season
# 0     Sunrisers Hyderabad         field  Hyderabad  2017-04-05    2017
# 1  Rising Pune Supergiant         field       Pune  2017-04-06    2017
# 2   Kolkata Knight Riders         field     Rajkot  2017-04-07    2017
